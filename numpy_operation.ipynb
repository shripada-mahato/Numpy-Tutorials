# %%
import numpy as np
arr = np.linspace(1,10,8)
print(arr)
# Out:
# [ 1.          2.28571429  3.57142857  4.85714286  6.14285714  7.42857143
#   8.71428571 10.        ]

# %%
import numpy as np
arr = np.ones((2,3))
con = arr.astype(int)
print(arr.dtype)
print(con.dtype)
# Out:
# float64
# int64
